# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/lustre/work/statgrads/vpiyush2/DeepCDR/SimplerDeepCDR'

# %%
pubchem_to_smiles = pd.read_csv('../data/CCLE/Cell_lines_annotations_20181226.txt', sep="\t", header=0)

# %%
pubchem_to_smiles.isnull().mean()
# Out:
# CCLE_ID                         0.000000
# depMapID                        0.002738
# Name                            0.273785
# Pathology                       0.301848
# Site_Primary                    0.273785
# Site_Subtype1                   0.273785
# Site_Subtype2                   0.273785
# Site_Subtype3                   0.273785
# Histology                       0.274470
# Hist_Subtype1                   0.274470
# Hist_Subtype2                   0.274470
# Hist_Subtype3                   0.274470
# Gender                          0.373717
# Life_Stage                      0.993155
# Age                             0.453114
# Race                            0.603696
# Geo_Loc                         0.934976
# inferred_ethnicity              0.290212
# Site_Of_Finding                 0.804244
# Disease                         0.772758
# Annotation_Source               0.273785
# Original.Source.of.Cell.Line    0.375770
# Characteristics                 0.525667
# ...

# %%
pubchem_to_smiles.head()
# Out:
#                                     CCLE_ID    depMapID       Name  \
# 0                                DMS53_LUNG  ACH-000698     DMS 53
# 1                    SW1116_LARGE_INTESTINE  ACH-000489     SW1116
# 2                             NCIH1694_LUNG  ACH-000431  NCI-H1694
# 3  P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707     P3HR-1
# 4  HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509     HuT 78
#
#     Pathology                        Site_Primary Site_Subtype1 Site_Subtype2  \
# 0     primary                                lung            NS            NS
# 1     primary                     large_intestine         colon            NS
# 2  metastasis                                lung            NS            NS
# 3  metastasis  haematopoietic_and_lymphoid_tissue            NS            NS
# 4     primary  haematopoietic_and_lymphoid_tissue          skin            NS
#
#   Site_Subtype3          Histology                      Hist_Subtype1  ...  \
# ...
